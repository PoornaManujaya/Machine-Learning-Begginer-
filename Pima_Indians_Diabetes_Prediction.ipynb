# %% [markdown]
# <a href="https://colab.research.google.com/github/PoornaManujaya/Machine-Learning-Begginer-/blob/main/Pima_Indians_Diabetes_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PIMA INDIANS DIABETES PREDICTION
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.

# %%
from numpy import loadtxt
import pandas as pd
from tensorflow.keras import Sequential
from keras.layers import Dense

# %%
df = pd.read_csv("diabetes.csv")

# %%
#Split data into dependent and independent variables
X = df.drop('Outcome', axis='columns')
y = df['Outcome']

# %%
# Define the keras model
model = Sequential()
# First hidden layer
model.add(Dense(12, input_dim= 8, activation='relu')) #contains 12 neurones, 8 inputs
# Second hidden layer
model.add(Dense(8, activation='relu'))
# Output layer
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(
    loss= 'binary_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy'])

# %%
# Fit the keras model
model.fit(X,y,epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4827 - accuracy: 0.7656
# Epoch 2/200
# 77/77 [==============================] - 0s 3ms/step - loss: 0.4805 - accuracy: 0.7747
# Epoch 3/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4845 - accuracy: 0.7682
# Epoch 4/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4736 - accuracy: 0.7708
# Epoch 5/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7786
# Epoch 6/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7669
# Epoch 7/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.7812
# Epoch 8/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7747
# Epoch 9/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.7826
# Epoch 10/200
# ...

# %%
# Evaluate the model
_,accuracy = model.evaluate(X,y)
print("Accuracy: %0.2f" % (accuracy * 100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4345 - accuracy: 0.8073
# Accuracy: 80.73
